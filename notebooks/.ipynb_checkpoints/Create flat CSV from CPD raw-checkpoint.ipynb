# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim

# %%
outdoor_results = pd.read_csv('../data/Outdoor_Water_Fountain_Sampling_Results_Table_082917.csv')
outdoor_results.columns = [_.strip() for _ in outdoor_results.columns]
outdoor_results.dtypes
# Out:
# park_name                           object
# fountain_number                     object
# location_description                object
# address                             object
# 2017_initial_result                 object
# 2017_initial_sample_date            object
# 2017_follow_up_result               object
# 2017_follow_up_sample_date          object
# 2017_epa_first_draw_result          object
# 2017_epa_first_draw_sample_date     object
# follow_up_field_result              object
# follow_up_field_sample_date         object
# unmarked_result                    float64
# unmarked_sample_date                object
# 2016_epa_first_draw_result          object
# 2016_epa_flush_30_sec               object
# 2016_epa_flush_10_min               object
# dtype: object

# %%
# Set all of the results to floats.
def to_float(init_val):
    if str(init_val).startswith('<'):
        val = float("%.2f" % float(init_val.replace('<','').strip()))
        return val
    elif init_val in ['-']:
        # This is a piece of crap in the dataset
        return np.nan
    return float(init_val)

for field in ['2017_follow_up_result', '2017_epa_first_draw_result', '2017_initial_result',
              'follow_up_field_result', '2016_epa_first_draw_result', '2016_epa_flush_10_min',
              '2016_epa_flush_30_sec']:
    outdoor_results[field] = outdoor_results[field].apply(lambda x: to_float(x))
outdoor_results.dtypes
# Out:
# park_name                           object
# fountain_number                     object
# location_description                object
# address                             object
# 2017_initial_result                float64
# 2017_initial_sample_date            object
# 2017_follow_up_result              float64
# 2017_follow_up_sample_date          object
# 2017_epa_first_draw_result         float64
# 2017_epa_first_draw_sample_date     object
# follow_up_field_result             float64
# follow_up_field_sample_date         object
# unmarked_result                    float64
# unmarked_sample_date                object
# 2016_epa_first_draw_result         float64
# 2016_epa_flush_30_sec              float64
# 2016_epa_flush_10_min              float64
# dtype: object

# %%
# Set dates
def set_date(init_val):
    if str(init_val) == '-':
        return None
    return pd.to_datetime(init_val).date()

for field in ['2017_initial_sample_date', '2017_follow_up_sample_date', '2017_epa_first_draw_sample_date',
              'follow_up_field_sample_date', 'unmarked_sample_date']:
    outdoor_results[field] = outdoor_results[field].apply(lambda x: set_date(x))
outdoor_results.head()
# Out:
#          park_name   fountain_number  \
# 0  ABBOTT (ROBERT)  Abbott #1 - High
# 1  ABBOTT (ROBERT)   Abbott #1 - Low
# 2  ABBOTT (ROBERT)         Abbott #2
# 3  ABBOTT (ROBERT)         Abbott #3
# 4  ABBOTT (ROBERT)         Abbott #4
#
#                                 location_description       address  \
# 0  In front of comfort station on 95th Street, No...  49 E 95TH ST
# 1  In front of comfort station on 95th Street, No...  49 E 95TH ST
# 2                      Southeast corner of pool deck  49 E 95TH ST
# 3        30 feet off South run of center walks track  49 E 95TH ST
# 4  Northwest corner of oval running track where w...  49 E 95TH ST
#
#    2017_initial_result 2017_initial_sample_date  2017_follow_up_result  \
# 0                 2.00               2017-04-21                    NaN
# 1                 2.00               2017-04-21                    NaN
# 2                 2.19               2017-04-21                    NaN
# 3                 2.00               2017-04-21                    NaN
# 4                 2.38               2017-04-21                    NaN
#
#   2017_follow_up_sample_date  2017_epa_first_draw_result  \
# 0                        NaT                         NaN
# 1                        NaT                         NaN
# 2                        NaT                         NaN
# 3                        NaT                         NaN
# 4                        NaT                         NaN
#
#   2017_epa_first_draw_sample_date  follow_up_field_result  \
# 0                             NaT                     NaN
# 1                             NaT                     NaN
# 2                             NaT                     NaN
# 3                             NaT                     NaN
# 4                             NaT                     NaN
#
#   follow_up_field_sample_date  unmarked_result unmarked_sample_date  \
# 0                         NaT              NaN                  NaT
# 1                         NaT              NaN                  NaT
# 2                         NaT              NaN                  NaT
# 3                         NaT              NaN                  NaT
# 4                         NaT              NaN                  NaT
#
#    2016_epa_first_draw_result  2016_epa_flush_30_sec  2016_epa_flush_10_min
# 0                       0.120                    NaN                    NaN
# 1                       0.120                    NaN                    NaN
# 2                       0.120                    NaN                    NaN
# 3                       0.245                    NaN                    NaN
# 4                       4.480                    NaN                    NaN

# %%
outdoor_results.dtypes
# Out:
# park_name                           object
# fountain_number                     object
# location_description                object
# address                             object
# 2017_initial_result                float64
# 2017_initial_sample_date            object
# 2017_follow_up_result              float64
# 2017_follow_up_sample_date          object
# 2017_epa_first_draw_result         float64
# 2017_epa_first_draw_sample_date     object
# follow_up_field_result             float64
# follow_up_field_sample_date         object
# unmarked_result                    float64
# unmarked_sample_date                object
# 2016_epa_first_draw_result         float64
# 2016_epa_flush_30_sec              float64
# 2016_epa_flush_10_min              float64
# dtype: object

# %%
outdoor_results['location_description'] = outdoor_results['location_description'].apply(lambda x: str(x).lower())

# %%
# Read in the next CSV
outdoor_status = pd.read_csv('../data/Outdoor_Water_Fountain_Status_Table_082917.csv')
outdoor_status = outdoor_status[['park_name','location_description','status']]
outdoor_status['location_description'] = outdoor_status['location_description'].apply(lambda x: x.lower())
outdoor_status = outdoor_status.drop_duplicates(subset=['park_name', 'location_description'], keep='last')
outdoor_status.head()
# Out:
#               park_name                               location_description  \
# 0       ABBOTT (ROBERT)  in front of comfort station on 95th street, no...
# 1       ABBOTT (ROBERT)                      southeast corner of pool deck
# 2       ABBOTT (ROBERT)        30 feet off south run of center walks track
# 3       ABBOTT (ROBERT)  northwest corner of oval running track where w...
# 4  ADA (SAWYER GARRETT)             on 113th street, east of tennis courts
#
#                                               status
# 0  Passed testing - returned to normal push-butto...
# 1  Passed testing - returned to normal push-butto...
# 2  Passed testing - returned to normal push-butto...
# 3  Passed testing - returned to normal push-butto...
# 4  Passed testing - returned to normal push-butto...

# %%
# Left merge because I really only care about the entries that I have a sample for, and the
# status tab is only just nice to have
outdoor = outdoor_results.merge(outdoor_status, how='left', on=['park_name', 'location_description'])
outdoor['indoor_outdoor'] = 'O'  # outdoor
outdoor.head()
# Out:
#          park_name   fountain_number  \
# 0  ABBOTT (ROBERT)  Abbott #1 - High
# 1  ABBOTT (ROBERT)   Abbott #1 - Low
# 2  ABBOTT (ROBERT)         Abbott #2
# 3  ABBOTT (ROBERT)         Abbott #3
# 4  ABBOTT (ROBERT)         Abbott #4
#
#                                 location_description       address  \
# 0  in front of comfort station on 95th street, no...  49 E 95TH ST
# 1  in front of comfort station on 95th street, no...  49 E 95TH ST
# 2                      southeast corner of pool deck  49 E 95TH ST
# 3        30 feet off south run of center walks track  49 E 95TH ST
# 4  northwest corner of oval running track where w...  49 E 95TH ST
#
#    2017_initial_result 2017_initial_sample_date  2017_follow_up_result  \
# 0                 2.00               2017-04-21                    NaN
# 1                 2.00               2017-04-21                    NaN
# 2                 2.19               2017-04-21                    NaN
# 3                 2.00               2017-04-21                    NaN
# 4                 2.38               2017-04-21                    NaN
#
#   2017_follow_up_sample_date  2017_epa_first_draw_result  \
# 0                        NaT                         NaN
# 1                        NaT                         NaN
# 2                        NaT                         NaN
# 3                        NaT                         NaN
# 4                        NaT                         NaN
#
#   2017_epa_first_draw_sample_date  follow_up_field_result  \
# 0                             NaT                     NaN
# 1                             NaT                     NaN
# 2                             NaT                     NaN
# 3                             NaT                     NaN
# 4                             NaT                     NaN
#
#   follow_up_field_sample_date  unmarked_result unmarked_sample_date  \
# 0                         NaT              NaN                  NaT
# 1                         NaT              NaN                  NaT
# 2                         NaT              NaN                  NaT
# 3                         NaT              NaN                  NaT
# 4                         NaT              NaN                  NaT
#
#    2016_epa_first_draw_result  2016_epa_flush_30_sec  2016_epa_flush_10_min  \
# 0                       0.120                    NaN                    NaN
# 1                       0.120                    NaN                    NaN
# 2                       0.120                    NaN                    NaN
# 3                       0.245                    NaN                    NaN
# 4                       4.480                    NaN                    NaN
#
#                                               status indoor_outdoor
# 0  Passed testing - returned to normal push-butto...              O
# 1  Passed testing - returned to normal push-butto...              O
# 2  Passed testing - returned to normal push-butto...              O
# 3  Passed testing - returned to normal push-butto...              O
# 4  Passed testing - returned to normal push-butto...              O

# %%
'The new data structure has %s entries.  Outdoor results had %s and outdoor samples had %s' %\
    (str(len(outdoor)), str(len(outdoor_results)), str(len(outdoor_status)))
# Out:
# 'The new data structure has 2024 entries.  Outdoor results had 2024 and outdoor samples had 1235'

# %%
geolocator = Nominatim()

def geocode_park(address_string):
    return geolocator.geocode(address_string + ', Chicago, IL')

# %%
locations = pd.DataFrame(outdoor['address'])
locations = locations.drop_duplicates().reset_index(drop=True)
locations.head()
# Out:
#                address
# 0         49 E 95TH ST
# 1       11250 S ADA ST
# 2  1919 N SEMINARY AVE
# 3       1301 W 14TH ST
# 4      550 E GRAND AVE

# %%
locations['lat'] = None
locations['lon'] = None
locations['tried'] = False

# %%
from time import sleep
import traceback
for i, location in enumerate(locations.to_dict('records')):
    if location['lat'] or not location['address'] or str(location['address']) != 'nan':
        continue
    try:
        l = geocode_park(location['address'])
        locations.ix[i, 'lat'] = l.latitude if l else None
        locations.ix[i, 'lon'] = l.longitude if l else None
    except Exception as e:
        print(location)
        traceback.print_exc()
        continue
    sleep(1)
locations.head()
# Out:
# {'address': nan, 'lat': None, 'lon': None}
# Traceback (most recent call last):
#   File "<ipython-input-99-fb4143f5688e>", line 7, in <module>
#     l = geocode_park(location['address'])
#   File "<ipython-input-74-d027f1745dd7>", line 4, in geocode_park
#     return geolocator.geocode(address_string + ', Chicago, IL')
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
#                address      lat      lon
# 0         49 E 95TH ST  41.7211 -87.6218
# 1       11250 S ADA ST  41.6883  -87.656
# 2  1919 N SEMINARY AVE  41.9166 -87.6552
# 3       1301 W 14TH ST   41.863 -87.6593
# 4      550 E GRAND AVE  41.8931 -87.6132

# %%
len(locations.loc[locations['lat'].isnull()])
# Out:
# 17

# %%
locations.to_csv('../data/locations.csv')

# %%
locations_dict = locations.to_dict('records')

# %%
locations_list = []
for row in locations_dict:
    if not row['lat']:
        l = geocode_park(row['address'])
        print(l)
        row['lat'] = l.latitude if l else None
        row['lon'] = l.longitude if l else None
    locations_list.append(row)
    locations = pd.DataFrame(locations_list)
locations_list
# Out:
# Abbott Park Senior Center, 49, East 95th Street, Lilydale, Chicago, Cook County, Illinois, 60628, United States of America
# 11250, South Ada Street, Placerdale, Chicago, Cook County, Illinois, 60643, United States of America
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in connect(self)
#    1399             self.sock = self._context.wrap_socket(self.sock,
# -> 1400                                                   server_hostname=server_hostname)
#    1401             if not self._context.check_hostname and self._check_hostname:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     400                          server_hostname=server_hostname,
# --> 401                          _context=self, _session=session)
#     402
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     807                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 808                     self.do_handshake()
#     809
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in do_handshake(self, block)
#    1060                 self.settimeout(None)
# -> 1061             self._sslobj.do_handshake()
#    1062         finally:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in do_handshake(self)
#     682         """Start the SSL/TLS handshake."""
# --> 683         self._sslobj.do_handshake()
#     684         if self.context.check_hostname:
#
# timeout: _ssl.c:733: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~/Documents/Coding/virtualenvs/waterfountains/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     525
# --> 526         response = self._open(req, data)
#     527
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _open(self, req, data)
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in https_open(self, req)
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#
# URLError: <urlopen error _ssl.c:733: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-63-fcfac2ccd37a> in <module>()
#       3 for row in locations_dict:
#       4     if not row['lat']:
# ----> 5         l = geocode_park(row['address'])
#       6         print(l)
#       7         row['lat'] = l.latitude if l else None
#
# <ipython-input-53-c240c52dc63b> in geocode_park(address_string)
#       2
#       3 def geocode_park(address_string):
# ----> 4     return geolocator.geocode(address_string + ', Chicago, IL')
#       5 geocode_park('2133 N MCVICKER')
#
# ~/Documents/Coding/virtualenvs/waterfountains/lib/python3.6/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     191         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     192         return self._parse_json(
# --> 193             self._call_geocoder(url, timeout=timeout), exactly_one
#     194         )
#     195
#
# ~/Documents/Coding/virtualenvs/waterfountains/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     161             elif isinstance(error, URLError):
#     162                 if "timed out" in message:
# --> 163                     raise GeocoderTimedOut('Service timed out')
#     164                 elif "unreachable" in message:
#     165                     raise GeocoderUnavailable('Service not available')
#
# GeocoderTimedOut: Service timed out

# %%
outdoor_dict = []
from time import sleep
for i, row in enumerate(outdoor.to_dict('records')):
    # print(row)
    location = geocode_park(row['address'])
    print(location)
    row['latitude'] = location.latitude if location else None
    row['longitude'] = location.longitude if location else None
    sleep(1)
    outdoor_dict.append(row)
pd.DataFrame(outdoor_dict).head()
# Out:
# Abbott Park Senior Center, 49, East 95th Street, Lilydale, Chicago, Cook County, Illinois, 60628, United States of America
# Abbott Park Senior Center, 49, East 95th Street, Lilydale, Chicago, Cook County, Illinois, 60628, United States of America
# Abbott Park Senior Center, 49, East 95th Street, Lilydale, Chicago, Cook County, Illinois, 60628, United States of America
# Abbott Park Senior Center, 49, East 95th Street, Lilydale, Chicago, Cook County, Illinois, 60628, United States of America
# Abbott Park Senior Center, 49, East 95th Street, Lilydale, Chicago, Cook County, Illinois, 60628, United States of America
# 11250, South Ada Street, Placerdale, Chicago, Cook County, Illinois, 60643, United States of America
# 11250, South Ada Street, Placerdale, Chicago, Cook County, Illinois, 60643, United States of America
# 11250, South Ada Street, Placerdale, Chicago, Cook County, Illinois, 60643, United States of America
# 11250, South Ada Street, Placerdale, Chicago, Cook County, Illinois, 60643, United States of America
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in connect(self)
#    1399             self.sock = self._context.wrap_socket(self.sock,
# -> 1400                                                   server_hostname=server_hostname)
#    1401             if not self._context.check_hostname and self._check_hostname:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     400                          server_hostname=server_hostname,
# --> 401                          _context=self, _session=session)
#     402
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     807                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 808                     self.do_handshake()
#     809
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in do_handshake(self, block)
#    1060                 self.settimeout(None)
# -> 1061             self._sslobj.do_handshake()
#    1062         finally:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in do_handshake(self)
#     682         """Start the SSL/TLS handshake."""
# --> 683         self._sslobj.do_handshake()
#     684         if self.context.check_hostname:
#
# timeout: _ssl.c:733: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~/Documents/Coding/virtualenvs/waterfountains/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     525
# --> 526         response = self._open(req, data)
#     527
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _open(self, req, data)
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in https_open(self, req)
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#
# URLError: <urlopen error _ssl.c:733: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-55-e8eb7f245ed3> in <module>()
#       3 for i, row in enumerate(outdoor.to_dict('records')):
#       4     # print(row)
# ----> 5     location = geocode_park(row['address'])
#       6     print(location)
#       7     row['latitude'] = location.latitude if location else None
#
# <ipython-input-53-c240c52dc63b> in geocode_park(address_string)
#       2
#       3 def geocode_park(address_string):
# ----> 4     return geolocator.geocode(address_string + ', Chicago, IL')
#       5 geocode_park('2133 N MCVICKER')
#
# ~/Documents/Coding/virtualenvs/waterfountains/lib/python3.6/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     191         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     192         return self._parse_json(
# --> 193             self._call_geocoder(url, timeout=timeout), exactly_one
#     194         )
#     195
#
# ~/Documents/Coding/virtualenvs/waterfountains/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     161             elif isinstance(error, URLError):
#     162                 if "timed out" in message:
# --> 163                     raise GeocoderTimedOut('Service timed out')
#     164                 elif "unreachable" in message:
#     165                     raise GeocoderUnavailable('Service not available')
#
# GeocoderTimedOut: Service timed out

# %%
outdoor.head()

# %%
outdoor.to_csv('../data/results.csv', index=False)
